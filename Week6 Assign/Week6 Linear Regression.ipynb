# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# !pip install sklearn

# %%
df = pd.read_csv(r'C:\Users\Riyaz\Desktop\lrlor\dataset\Linear Regression_ Problem Data Set.csv')

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df.nsmallest(5, 'Yearly Amount Spent')
# Out:
#                              Email  \
# 225  alexandra26@summers-davis.com
# 303       brandon77@richardson.com
# 415              brian51@cook.info
# 299       morganorozco@hotmail.com
# 173        fischermonica@gmail.com
#
#                                                Address       Avatar  \
# 225            Unit 7032 Box 7016\r\nDPO AE 44749-2992         Navy
# 303  109 Jessica Manor\r\nNorth Patriciashire, PR 8...   GhostWhite
# 415  0508 Terrance Cliff\r\nRebekahtown, NC 48724-8308  SaddleBrown
# 299    0001 Mack Mill\r\nNorth Jennifer, NE 42021-5936    LightPink
# 173  9847 Michael Plaza Suite 837\r\nLake Christoph...         Navy
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 225            32.836941    10.256549        36.143908              0.789520
# 303            30.816201    11.851399        36.925043              1.084585
# 415            31.517122    10.745189        38.791235              1.428824
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
# a = sorted(df['Avg. Session Length'])
A = df['Avg. Session Length']
B = df['Time on App']
C = df['Time on Website']
D = df['Length of Membership']

u = df['Yearly Amount Spent']

# fig, axes = plt.subplots(nrows=2, ncols=1, figsize = (4,6), dpi = 100)
# # sns.lmplot(data = df, x = 'Avg. Session Length', y = 'Yearly Amount Spent')
# axes[0].plot(A,u,'.', alpha = 0.6) #dur_d,inter_d,color='purple', lw=0.5, alpha=0.5, linestyle='dashed',marker='+',markersize=10,markeredgecolor='red',markeredgewidth=3
# axes[1].scatter(x=B,y=u)


plt.figure(figsize=(6,4),dpi=150)
plt.subplot(2,2,1)
sns.scatterplot(x=A,y=u, alpha = 0.4)
# sns.regplot(x=A,y=u)

plt.subplot(2,2,2)
# sns.histplot(x=C,y=u)
sns.scatterplot(x=B,y=u, alpha = 0.4)

plt.subplot(2,2,3)
sns.scatterplot(x=C,y=u, alpha = 0.4)

plt.subplot(2,2,4)
sns.scatterplot(x=D,y=u, alpha = 0.4)
# sns.distplot(x=D)

plt.tight_layout();

# %%
# sns.scatterplot(data = df, x = 'Time on App', y = 'Yearly Amount Spent')
# sns.scatterplot(data = df, x = 'Time on Website', y = 'Yearly Amount Spent')
# sns.regplot(data = df, x = 'Length of Membership', y = 'Yearly Amount Spent')

# %%
import random
time_spend = np.random.randint(0,100,60)
time_spend
# Out:
# array([50, 80, 41, 95, 29, 50, 58, 83, 70, 67, 90, 48, 22, 37, 27, 75, 67,
#        90, 72,  6, 41, 96, 59, 44, 49, 36, 77, 22, 88, 31, 16, 18, 91, 42,
#         3, 75, 60, 90, 34,  4,  0, 55, 67,  0, 66, 70, 36, 32, 79,  9, 87,
#        36, 81, 29, 41, 33, 53, 27, 93, 39])

# %%
np.polyfit(A,u,1) # '1' degree, polyfit for simple linear regression
# Out:
# array([  28.37477054, -438.5627435 ])

# %%
pred_yr_amt_A =  28.37477054*time_spend + -438.5627435

# %%
sns.scatterplot(x=A,y=u)
plt.plot(time_spend,pred_yr_amt_A,'r')
plt.xlim(10,40)
plt.ylim(0,800)
# Out:
# (0.0, 800.0)

# %%
np.polyfit(B,u,1)
# Out:
# array([39.8344913 , 19.20931241])

# %%
pred_yr_amt_B =  39.8344913*time_spend + 19.20931241

# %%
sns.scatterplot(x=B,y=u)
plt.plot(time_spend,pred_yr_amt_B,'r')
plt.xlim(0,20)
plt.ylim(0,800)
# Out:
# (0.0, 800.0)

# %%
np.polyfit(C,u,1)
# Out:
# array([-2.07283837e-01,  5.06996070e+02])

# %%
pred_yr_amt_C =  -2.07283837e-01*time_spend + 5.06996070e+02

# %%
sns.scatterplot(x=C,y=u)
plt.plot(time_spend,pred_yr_amt_C,'r')
plt.xlim(30,40)
plt.ylim(0,800)
# Out:
# (0.0, 800.0)

# %%
np.polyfit(D,u,1)
# Out:
# array([ 64.21868432, 272.39978606])

# %%
pred_yr_amt_D =  64.21868432*time_spend + 272.39978606

# %%
sns.scatterplot(x=D,y=u)
plt.plot(time_spend,pred_yr_amt_D,'r')
plt.xlim(0,10)
plt.ylim(0,800)
# Out:
# (0.0, 800.0)

# %%
# sns.heatmap(df)

# %%
spend_lenght_member = 5
pred_yr_amt =  64.21868432*5 + 272.39978606

# %%
pred_yr_amt
# Out:
# 593.4932076599999

# %%
np.polyfit(A,u,3)
# Out:
# array([ 1.74012404e+00, -1.71571818e+02,  5.66193898e+03, -6.20399435e+04])

# %%
sort_time_spend = np.sort(time_spend)
pred_yr_amt_A_new =  (1.74012404e+00*sort_time_spend**3 + -1.71571818e+02*sort_time_spend**2 + 5.66193898e+03*sort_time_spend**1 + -6.20399435e+04*sort_time_spend**0)
# pred_yr_amt_A_new =  (0.70904146*time_spend**2 + -18.47484549*time_spend**1 + 334.63210649*time_spend**0)

# %%
# pred_yr_amt_D_new

# %%
sns.scatterplot(x=A,y=u)
plt.plot(sort_time_spend,pred_yr_amt_A_new,'r')
# sns.scatterplot(x=time_spend, y=pred_yr_amt_A_new)
plt.xlim(29,37.5)
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
# sns.scatterplot(x='time_spend', y='pred_yr_amt_A_new')


# plt.figure(figsize=(6,4),dpi=150)
plt.subplot(1,1,1)
# sns.scatterplot(x=time_spend, y=pred_yr_amt_A_new)
plt.plot(sort_time_spend,pred_yr_amt_A_new,'r')

# %%
# A = df['Avg. Session Length']
# B = df['Time on App']
# C = df['Time on Website']
# D = df['Length of Membership']

# u = df['Yearly Amount Spent']


fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(7,5),dpi=100)

axes[0,0].plot(A,u,'.')
axes[0,0].set_ylabel("Yearly Amount Spent")
axes[0,0].set_title("Avg. Session Length")

axes[0,1].plot(B,u,'.')
axes[0,1].set_title("Time on App")
axes[0,1].set_ylabel("Yearly Amount Spent")

axes[1,0].plot(C,u,'.')
axes[1,0].set_title("Time on Website");
axes[1,0].set_ylabel("Yearly Amount Spent")

axes[1,1].plot(D,u,'.')
axes[1,1].set_title("Length of Membership");
axes[1,1].set_ylabel("Yearly Amount Spent")

plt.tight_layout();

# %%
sns.pairplot(df,diag_kind='kde',corner=True) #kernal density estimator

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
X = df.drop(['Yearly Amount Spent','Email','Address','Avatar'],axis=1)

# %%
y = df['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split

# %%
# help(train_test_split)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.count()
# Out:
# Avg. Session Length     350
# Time on App             350
# Time on Website         350
# Length of Membership    350
# dtype: int64

# %%
X_test.count()
# Out:
# Avg. Session Length     150
# Time on App             150
# Time on Website         150
# Length of Membership    150
# dtype: int64

# %%
df.count()
# Out:
# Email                   500
# Address                 500
# Avatar                  500
# Avg. Session Length     500
# Time on App             500
# Time on Website         500
# Length of Membership    500
# Yearly Amount Spent     500
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression # creating model estimator

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.

# All of these are loss functions, because we want to minimize them.

# %%
test_predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
MAE = mean_absolute_error(y_test,test_predictions)
MSE = mean_squared_error(y_test,test_predictions)
RMSE = np.sqrt(MSE)

# %%
y.mean()
# Out:
# 499.31403825859053

# %%
MAE
# Out:
# 8.426091641432116

# %%
RMSE
# Out:
# 10.193897260863155

# %%
100*RMSE/y.mean() # percentage error
# Out:
# 2.041580344188885

# %%
sns.regplot(x=test_predictions, y=y_test)
# Out:
# <AxesSubplot:ylabel='Yearly Amount Spent'>

# %%
# sns.scatterplot(x=test_predictions, y=y_test)
# test_predictions
# y_test

# %%
plt.figure(figsize=(10,6),dpi=150)
sns.kdeplot(x=test_predictions, label= 'predctions')
sns.kdeplot(x=y_test, label = 'actual results')

plt.legend()

# %%
# test_predictions = model.predict(X_test)

test_res = y_test - test_predictions

# %%
test_res
# Out:
# 361    -2.636795
# 73     -7.800375
# 374    -8.463174
# 155     1.953775
# 104    -0.051825
#          ...
# 266    10.327176
# 23     15.027984
# 222   -16.778237
# 261    -6.021734
# 426    -4.371832
# Name: Yearly Amount Spent, Length: 150, dtype: float64

# %%
sns.scatterplot(x=y_test,y=test_res)
plt.axhline(y=0, color='r', linestyle='--')

# %%
len(test_res) #residuals
# Out:
# 150

# %%
# sns.displot(test_res,bins=25,kde=True)

# %%
# import scipy as sp

# %%
# Create a figure and axis to plot on
#fig, ax = plt.subplots(figsize=(6,8),dpi=100) #...........
# probplot returns the raw values if needed
# we just want to see the plot, so we assign these values to _
#_ = sp.stats.probplot(test_res,plot=ax) #............

# %%
#Retraining Model on Full Data

# %%
final_model_6 = LinearRegression()

# %%
final_model_6.fit(X,y)
# Out:
# LinearRegression()

# %%
u_hat = final_model_6.predict(X)

# %%
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(7,5),dpi=100)


axes[0,0].plot(A,u,'.')
axes[0,0].plot(A,u_hat,'.','r')
axes[0,0].set_ylabel("Yearly Amount Spent")
axes[0,0].set_title("Avg. Session Length")

axes[0,1].plot(B,u,'.')
axes[0,1].plot(B,u_hat,'.','r')
axes[0,1].set_title("Time on App")
axes[0,1].set_ylabel("Yearly Amount Spent")

axes[1,0].plot(C,u,'.')
axes[1,0].plot(C,u_hat,'.','r')
axes[1,0].set_title("Time on Website");
axes[1,0].set_ylabel("Yearly Amount Spent")

axes[1,1].plot(D,u,'.')
axes[1,1].plot(D,u_hat,'.','r')
axes[1,1].set_title("Length of Membership");
axes[1,1].set_ylabel("Yearly Amount Spent")


plt.tight_layout();

# %%
plt.figure(figsize=(6,4),dpi=130)
plt.subplot(2,2,1)
sns.scatterplot(x=A,y=u, alpha = 0.6)
sns.scatterplot(x=A,y=u_hat, alpha = 0.2,color='red')
# sns.regplot(x=A,y=u)

plt.subplot(2,2,2)
# sns.histplot(x=C,y=u)
sns.scatterplot(x=B,y=u, alpha = 0.6)
sns.scatterplot(x=B,y=u_hat, alpha = 0.2,color='red')

plt.subplot(2,2,3)
sns.scatterplot(x=C,y=u, alpha = 0.6)
sns.scatterplot(x=C,y=u_hat, alpha = 0.2,color='red')

plt.subplot(2,2,4)
sns.scatterplot(x=D,y=u, alpha = 0.6)
sns.scatterplot(x=D,y=u_hat, alpha = 0.2,color='red')
# sns.distplot(x=D)

plt.tight_layout();

# %%
res = u-u_hat

# %%
sns.scatterplot(x=u,y=res)
plt.axhline(y=0, color='r', linestyle='--')

# %%
final_model_6.coef_
# Out:
# array([25.73427108, 38.70915381,  0.43673884, 61.57732375])

# %%
coeff_df = pd.DataFrame(final_model_6.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                       Coefficient
# Avg. Session Length     25.734271
# Time on App             38.709154
# Time on Website          0.436739
# Length of Membership    61.577324

# %%
# with all other units fixed increase one unit in Avg. Session length will increase yearly amount spend by 25.734271

df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
import warnings
# current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
#predction  on new data

campaign_6 = [[40,20,50,1]]

# %%
final_model_6.predict(campaign_6)
# Out:
# array([835.37392984])

# %%
# Model Persistence (Saving and Loading a Model)
from joblib import dump, load

# %%
dump(final_model_6, 'sales_model_week6.joblib')
# Out:
# ['sales_model_week6.joblib']

# %%
loaded_model_6 = load('sales_model_week6.joblib')

# %%
loaded_model_6.predict(campaign_6)
# Out:
# array([835.37392984])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, test_predictions)
# Out:
# 0.9808757641125855

# %%
# from sklearn.metrics import accuracy_score

# %%
# accuracy_score(y_test, test_predictions)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
polynomial_converter = PolynomialFeatures(degree=2,include_bias=False)

# %%
polynomial_features = polynomial_converter.fit_transform(X)

# %%
polynomial_features.shape
# Out:
# (500, 14)

# %%
X.shape
# Out:
# (500, 4)

# %%
X.iloc[0]
# Out:
# Avg. Session Length     34.497268
# Time on App             12.655651
# Time on Website         39.577668
# Length of Membership     4.082621
# Name: 0, dtype: float64

# %%
polynomial_features[0]
# Out:
# array([  34.49726773,   12.65565115,   39.57766802,    4.08262063,
#        1190.0614805 ,  436.58538593, 1365.32140961,  140.839257  ,
#         160.16550601,  500.88115975,   51.66822251, 1566.39180586,
#         161.58060406,   16.66779123])

# %%
model_poly = LinearRegression(fit_intercept=True)

# %%
model_poly.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_predictions_poly = model_poly.predict(X_test)

# %%
MAE = mean_absolute_error(y_test,test_predictions_poly)
MSE = mean_squared_error(y_test,test_predictions_poly)
RMSE = np.sqrt(MSE)

# %%
MAE
# Out:
# 8.426091641432116

# %%
RMSE
# Out:
# 10.193897260863155

# %%
# TRAINING ERROR PER DEGREE
train_rmse_errors = []
# TEST ERROR PER DEGREE
test_rmse_errors = []

for d in range(1,10):
    
    # CREATE POLY DATA SET FOR DEGREE "d"
    polynomial_converter = PolynomialFeatures(degree=d,include_bias=False)
    poly_features = polynomial_converter.fit_transform(X)
    
    # SPLIT THIS NEW POLY DATA SET
    X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)
    
    # TRAIN ON THIS NEW POLY SET
    model = LinearRegression(fit_intercept=True)
    model.fit(X_train,y_train)
    
    # PREDICT ON BOTH TRAIN AND TEST
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    
    # Calculate Errors
    
    # Errors on Train Set
    train_RMSE = np.sqrt(mean_squared_error(y_train,train_pred))
    
    # Errors on Test Set
    test_RMSE = np.sqrt(mean_squared_error(y_test,test_pred))

    # Append errors to lists for plotting later
    
   
    train_rmse_errors.append(train_RMSE)
    test_rmse_errors.append(test_RMSE)

# %%
train_rmse_errors
# Out:
# [10.336893843068,
#  10.243727794053235,
#  10.050701181853034,
#  9.518700904041387,
#  8.562408366152074,
#  6.857866492011964,
#  5.6972604598929095,
#  3.8217447750578555,
#  2.6462411086429936]

# %%
test_rmse_errors
# Out:
# [8.933815066978667,
#  9.238368636026756,
#  9.745197242944903,
#  12.231570966405721,
#  78.06462446290804,
#  409.09915631067815,
#  4927.645676988263,
#  54633.1693281419,
#  54204.94648062261]

# %%
plt.plot(range(1,5),train_rmse_errors[:4],label='TRAIN')
plt.plot(range(1,5),test_rmse_errors[:4],label='TEST')
plt.xlabel("Polynomial Complexity")
plt.ylabel("RMSE")
plt.legend()

# %%
final_poly_converter = PolynomialFeatures(degree=2,include_bias=False)

# %%
final_model = LinearRegression()

# %%
final_model.fit(final_poly_converter.fit_transform(X),y)
# Out:
# LinearRegression()

# %%
dump(final_model, 'final_poly_model.joblib')
# Out:
# ['final_poly_model.joblib']

# %%
dump(final_poly_converter,'final_poly_converter.joblib')
# Out:
# ['final_poly_converter.joblib']

# %%
loaded_poly = load('final_poly_converter.joblib')
loaded_model = load('final_poly_model.joblib')

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0     835 Frank Tunnel\r\nWrightmouth, MI 82180-9605            Violet
# 1   4547 Archer Common\r\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\r\nCobbborough,...            Bisque
# 3  1414 David Throughway\r\nPort Jason, OH 22070-...       SaddleBrown
# 4  14023 Rodriguez Passage\r\nPort Jacobville, PR...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
campaign = [[40,20,50,1]]

# %%
campaign_poly = loaded_poly.transform(campaign)

# %%
final_model.predict(campaign_poly)
# Out:
# array([830.51841717])
